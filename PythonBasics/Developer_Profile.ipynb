# %% [markdown]
#  In this session will explain
#  Variables, string, integer, float, boolean, print(), type()

# %%
YourName = 'Ashwini'
Age = 38
City = 'Bangalore'
College= 'Biju Patnaik University of Technology'
Company= 'Shell'
Current_learning_topic = 'Gen AI'
Years_of_experience = 13
Whether_you_like_Python = True
Your_expected_salary_after_learning_Python = 20000000

# %%
print(YourName)
print(Age)
print(City)
print(College)
print(Company)
print(Current_learning_topic)
print(Years_of_experience)
print(Whether_you_like_Python)
print(Your_expected_salary_after_learning_Python)
# Out:
# Ashwini
# 38
# Bangalore
# Biju Patnaik University of Technology
# Shell
# Gen AI
# 13
# True
# 20000000

# %%
print('type of YourName:', type(YourName))
print('type of Age:', type(Age))
print('type of City:', type(City))   
print('type of College:', type(College))
print('type of Company:', type(Company))
print('type of Current_learning_topic:', type(Current_learning_topic))
print('type of Years_of_experience:', type(Years_of_experience))
print('type of Whether_you_like_Python:', type(Whether_you_like_Python))
print('type of Your_expected_salary_after_learning_Python:', type(Your_expected_salary_after_learning_Python))
# Out:
# type of YourName: <class 'str'>
# type of Age: <class 'int'>
# type of City: <class 'str'>
# type of College: <class 'str'>
# type of Company: <class 'str'>
# type of Current_learning_topic: <class 'str'>
# type of Years_of_experience: <class 'int'>
# type of Whether_you_like_Python: <class 'bool'>
# type of Your_expected_salary_after_learning_Python: <class 'int'>
