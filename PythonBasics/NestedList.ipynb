# %%
students = [
["Rahul", 21, "Python"],
["Priya", 22, "Data Science"],
["Aman", 20, "Machine Learning"]
]
students
# Out:
# [['Rahul', 21, 'Python'],
#  ['Priya', 22, 'Data Science'],
#  ['Aman', 20, 'Machine Learning']]

# %%
#Print Rahul's name
print(students[0][0])

#Print Priya's age
print(students[1][1])

#Print Aman's course
print(students[2][2])

#Print the complete record of Priya
print(students[1])
# Out:
# Rahul
# 22
# Machine Learning
# ['Priya', 22, 'Data Science']

# %%
#Change Rahul's course to "AI"
students[0][2] = "AI"

#Add another student record manually
students.append(["Neha", 23, "Cyber Security"])

#Print the updated nested list
print(students)
# Out:
# [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning'], ['Neha', 23, 'Cyber Security']]
